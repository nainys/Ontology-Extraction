# %%
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
import os

import gensim
from gensim import corpora
from gensim.models import LsiModel

# %%
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

summary_dir = './Datasets/Summaries'
summaries = os.listdir(summary_dir)

# %%
def clean(doc):
    f = open(os.path.join(summary_dir, doc),"r")
    contents = f.read()

    stop_free = " ".join([i for i in contents.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    f.close()
    return normalized

# %%
doc_clean = [clean(doc).split() for doc in summaries]

# %%
dictionary = corpora.Dictionary(doc_clean) 

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
lsamodel = LsiModel(doc_term_matrix, id2word = dictionary)  # train model
print(lsamodel.print_topics(-1))
# Out:
# [(0, '0.243*"word" + 0.215*"evaluation" + 0.214*"rule" + 0.205*"language" + 0.197*"sentence" + 0.181*"grammar" + 0.178*"interpretation" + 0.165*"task" + 0.159*"model" + 0.156*"set"'), (1, '0.426*"evaluation" + 0.323*"assessment" + 0.308*"task" + 0.256*"user" + 0.232*"technology" + 0.218*"project" + 0.189*"data" + -0.185*"interpretation" + 0.170*"system" + -0.164*"sentence"'), (2, '-0.425*"word" + 0.404*"interpretation" + -0.261*"rule" + 0.225*"sentence" + 0.223*"clause" + 0.221*"reading" + 0.169*"ellipsis" + 0.165*"source" + -0.160*"model" + 0.159*"ambiguity"'), (3, '-0.549*"rule" + 0.479*"word" + -0.335*"grammar" + 0.259*"model" + -0.215*"feature" + -0.138*"structure" + -0.131*"tree" + 0.100*"corpus" + 0.083*"speech" + 0.081*"probability"'), (4, '0.390*"discourse" + -0.320*"clause" + -0.288*"rule" + -0.260*"reading" + -0.253*"source" + -0.232*"ellipsis" + -0.194*"word" + 0.156*"model" + 0.130*"theory" + 0.124*"ambiguity"'), (5, '0.514*"rule" + -0.355*"feature" + -0.303*"term" + -0.264*"tree" + -0.223*"grammar" + -0.193*"structure" + 0.174*"discourse" + 0.168*"interpretation" + 0.146*"word" + -0.126*"node"'), (6, '-0.537*"noun" + -0.537*"phrase" + -0.180*"term" + -0.166*"pronoun" + 0.157*"language" + -0.147*"possessive" + 0.142*"ambiguity" + 0.141*"interpretation" + 0.138*"grammar" + 0.109*"theory"'), (7, '-0.640*"term" + 0.256*"tree" + -0.225*"dictionary" + 0.183*"model" + -0.176*"feature" + -0.154*"word" + 0.140*"noun" + 0.135*"phrase" + 0.115*"grammar" + -0.115*"discipline"'), (8, '0.384*"model" + -0.279*"sentence" + -0.268*"noun" + 0.217*"discourse" + 0.214*"agent" + 0.202*"belief" + -0.174*"ambiguity" + -0.166*"phrase" + -0.146*"word" + 0.141*"utterance"'), (9, '0.544*"tree" + -0.433*"grammar" + 0.249*"tag" + 0.218*"node" + 0.204*"derivation" + -0.164*"feature" + 0.162*"term" + -0.142*"unification" + 0.129*"set" + -0.128*"algorithm"'), (10, '-0.345*"word" + 0.333*"model" + -0.304*"structure" + -0.285*"feature" + 0.279*"term" + -0.241*"discourse" + 0.179*"language" + 0.141*"noun" + 0.121*"set" + 0.118*"dictionary"'), (11, '0.319*"language" + -0.304*"algorithm" + -0.243*"sentence" + -0.231*"grammar" + 0.186*"semantic" + -0.181*"parse" + -0.172*"corpus" + -0.171*"term" + 0.164*"feature" + -0.148*"discourse"'), (12, '-0.394*"belief" + -0.351*"agent" + 0.235*"model" + 0.196*"feature" + -0.180*"sentence" + -0.168*"action" + -0.163*"evidence" + -0.155*"text" + 0.148*"interpretation" + -0.138*"plan"'), (13, '0.329*"feature" + 0.234*"corpus" + -0.222*"language" + 0.194*"ambiguity" + 0.185*"belief" + -0.180*"preference" + 0.165*"tag" + -0.155*"semantic" + 0.149*"agent" + -0.147*"meaning"'), (14, '0.405*"function" + -0.251*"grammar" + -0.190*"word" + 0.186*"text" + -0.183*"tree" + 0.173*"semantic" + 0.169*"training" + -0.169*"interpretation" + 0.159*"corpus" + 0.156*"feature"'), (15, '-0.456*"text" + -0.356*"vehicle" + 0.281*"function" + 0.185*"sentence" + -0.176*"type" + -0.173*"car" + -0.171*"right" + -0.139*"context" + -0.138*"two" + -0.133*"accident"'), (16, '-0.370*"preference" + 0.304*"sentence" + -0.254*"corpus" + -0.246*"grammar" + 0.236*"algorithm" + -0.207*"function" + -0.181*"tag" + 0.145*"rule" + 0.135*"model" + -0.129*"utterance"'), (17, '-0.324*"corpus" + 0.240*"preference" + -0.232*"semantic" + -0.220*"tag" + 0.214*"function" + -0.170*"constraint" + 0.164*"algorithm" + -0.144*"structure" + 0.139*"feature" + 0.129*"theory"'), (18, '0.327*"algorithm" + -0.284*"model" + 0.282*"language" + -0.271*"sentence" + -0.248*"preference" + 0.183*"theory" + 0.182*"set" + 0.150*"class" + -0.126*"feature" + -0.125*"structure"'), (19, '0.327*"case" + -0.284*"sentence" + 0.233*"semantic" + 0.206*"meaning" + 0.193*"verb" + 0.192*"algorithm" + 0.184*"data" + -0.182*"language" + -0.178*"text" + 0.167*"slot"'), (20, '0.345*"algorithm" + -0.263*"function" + 0.224*"belief" + 0.175*"corpus" + 0.173*"pronoun" + -0.167*"agent" + -0.165*"cue" + -0.147*"pause" + -0.142*"grammar" + 0.134*"constraint"'), (21, '-0.407*"belief" + 0.385*"agent" + 0.26 ...

# %%
conceptMap = dict()
for tup in lsamodel.print_topics(-1):
    s = tup[1]
    s = s.split('+')
    l = []
    for ele in s:
        l.append(ele[:-1])
    l1 = []
    for ele in l:
        t = ele.split('"')
        l1.append(t[1])
    conceptMap[tup[0]] = l1

# %%
conceptMap
# Out:
# {0: ['word',
#   'evaluation',
#   'rule',
#   'language',
#   'sentence',
#   'grammar',
#   'interpretation',
#   'task',
#   'model',
#   'set'],
#  1: ['evaluation',
#   'assessment',
#   'task',
#   'user',
#   'technology',
#   'project',
#   'data',
#   'interpretation',
#   'system',
#   'sentence'],
#  2: ['word',
#   'interpretation',
#   'rule',
#   'sentence',
#   'clause',
#   'reading',
#   'ellipsis',
#   'source',
#   'model',
#   'ambiguity'],
#  3: ['rule',
#   'word',
#   'grammar',
#   'model',
#   'feature',
#   'structure',
#   'tree',
#   'corpus',
#   'speech',
#   'probability'],
#  4: ['discourse',
#   'clause',
#   'rule',
#   'reading',
#   'source',
#   'ellipsis',
#   'word',
#   'model',
#   'theory',
#   'ambiguity'],
#  5: ['rule',
#   'feature',
#   'term',
#   'tree',
#   'grammar',
#   'structure',
#   'discourse',
#   'interpretation',
#   'word',
#   'node'],
#  6: ['noun',
#   'phrase',
#   'term',
#   'pronoun',
#   'language',
#   'possessive',
#   'ambiguity',
#   'interpretation',
#   'grammar',
#   'theory'],
#  7: ['term',
#   'tree',
#   'dictionary',
#   'model',
#   'feature',
#   'word',
#   'noun',
#   'phrase',
#   'grammar',
#   'discipline'],
#  8: ['model',
#   'sentence',
#   'noun',
#   'discourse',
#   'agent',
#   'belief',
#   'ambiguity',
#   'phrase',
#   'word',
#   'utterance'],
#  9: ['tree',
#   'grammar',
#   'tag',
#   'node',
#   'derivation',
#   'feature',
#   'term',
#   'unification',
#   'set',
#   'algorithm'],
#  10: ['word',
#   'model',
#   'structure',
#   'feature',
#   'term',
#   'discourse',
#   'language',
#   'noun',
#   'set',
#   'dictionary'],
#  11: ['language',
#   'algorithm',
#   'sentence',
#   'grammar',
#   'semantic',
#   'parse',
#   'corpus',
#   'term',
#   'feature',
#   'discourse'],
#  12: ['belief',
#   'agent',
#   'model',
#   'feature',
#   'sentence',
#   'action',
#   'evidence',
#   'text',
#   'interpretation',
#   'plan'],
#  13: ['feature',
#   'corpus',
#   'language',
#   'ambiguity',
#   'belief',
#   'preference',
#   'tag',
#   'semantic',
#   'agent',
#   'meaning'],
#  14: ['function',
#   'grammar',
#   'word',
#   'text',
#   'tree',
#   'semantic',
#   'training',
#   'interpretation',
#   'corpus',
#   'feature'],
#  15: ['text',
#   'vehicle',
#   'function',
#   'sentence',
#   'type',
#   'car',
#   'right',
#   'context',
#   'two',
#   'accident'],
#  16: ['preference',
#   'sentence',
#   'corpus',
#   'grammar',
#   'algorithm',
#   'function',
#   'tag',
#   'rule',
#   'model',
#   'utterance'],
#  17: ['corpus',
#   'preference',
#   'semantic',
#   'tag',
#   'function',
#   'constraint',
#   'algorithm',
#   'structure',
#   'feature',
#   'theory'],
#  18: ['algorithm',
#   'model',
#   'language',
#   'sentence',
#   'preference',
#   'theory',
#   'set',
#   'class',
#   'feature',
#   'structure'],
#  19: ['case',
#   'sentence',
#   'semantic',
#   'meaning',
#   'verb',
#   'algorithm',
#   'data',
#   'language',
#   'text',
#   'slot'],
#  20: ['algorithm',
#   'function',
#   'belief',
#   'corpus',
#   'pronoun',
#   'agent',
#   'cue',
#   'pause',
#   'grammar',
#   'constraint'],
#  21: ['belief',
#   'agent',
#   'strategy',
#   'evidence',
#   'plan',
#   'cue',
#   'focus',
#   'pause',
#   'task',
#   'explicitwarrant'],
#  22: ['theory',
#   'clause',
#   'complexity',
#   'structure',
#   'unification',
#   'subordinate',
#   'lexical',
#   'main',
#   'role',
#   'algorithm'],
#  23: ['case',
#   'slot',
#   'algorithm',
#   'frame',
#   'cluster',
#   'dependency',
#   'semantic',
#   'meaning',
#   'relation',
#   'model'],
#  24: ['clause',
#   'constraint',
#   'sentence',
#   'meaning',
#   'subordinate',
#   'nonmonotonic',
#   'role',
#   'main',
#   'pronoun',
#   'default'],
#  25: ['verb',
#   'tag',
#   'lexical',
#   'collocation',
#   'chunk',
#   'np',
#   'constraint',
#   'semantic',
#   'phrase',
#   'corpus'],
#  26: ['np',
#   'pronoun',
#   'structure',
#   'context',
#   'preference',
#   'control',
#   'function',
#   'cluster',
#   'clause',
#   'possessive'],
#  27: ['nonmonotonic',
#   'default',
#   'set',
#   'control',
#   'constraint',
#   'sort',
#   'processing',
#   'input',
#   'pronoun',
#   'value'],
#  28: ['control',
#   'strategy',
#   'plan',
#   'shift',
#   'action',
#   'relation',
#   'utterance',
#   'algorithm',
#   'task',
#   'obligation'],
#  29: ['tag',
#   'chunk',
#   'relation',
#   'algorithm',
#   'function',
#   'structure',
#   'temporal',
#   'parse',
#   'tree',
#   'strategy'],
#  30: ['vector',
#   'context',
#   'verb',
#   'type',
#   'text',
#   'collocation',
#   'theory',
#   'meaning',
#   'control',
#   'clause'],
#  31: ['cluster',
#   'constraint',
#   'structure',
#   'clustering',
#   'nonmonotonic',
#   'tag',
#   'derivation',
#   'node',
#   'verb',
#   'lexical'],
#  32: ['control',
#   'action',
#   'strategy',
#   'type',
#   'plan',
#   'system',
#   'obligation',
#   'vector',
#   'context',
#   'nonmonotonic'],
#  33: ['control',
#   'constraint',
#   'clause',
#   'np',
#   'cluster',
#   'type',
#   'verb',
#   'meaning',
#   'corpus',
#   'datr'],
#  34: ['nonmonotonic',
#   'training',
#   'construction',
#   'data',
#   'set',
#   'vector',
#   'corpus',
#   'constraint',
#   'np',
#   'case'],
#  35: ['nonmonotonic',
#   'node',
#   'chunk',
#   'structure',
#   'relation',
#   'datr',
#   'derivation',
#   'feature',
#   'vector',
#   'cluster'],
#  36: ['lexical',
#   'language',
#   'nonmonotonic',
#   'value',
#   'cluster',
#   'generation',
#   'system',
#   'structure',
#   'case',
#   'clustering'],
#  37: ['class',
#   'training',
#   'control',
#   'chunk',
#   'temporal',
#   'corpus',
#   'relation',
#   'information',
#   'complexity',
#   'data'],
#  38: ['construction',
#   'dictionary',
#   'chunk',
#   'prolog',
#   'unification',
#   'lexical',
#   'tag',
#   'antecedent',
#   'set',
#   'verb'],
#  39: ['nlg',
#   'system',
#   'analysis',
#   'class',
#   'generation',
#   'chunk',
#   'training',
#   'dictionary',
#   'lexical',
#   'possessive'],
#  40: ['type',
#   'presupposition',
#   'chunk',
#   'verb',
#   'parse',
#   'set',
#   'constraint',
#   'machine',
#   'inference',
#   'equation'],
#  41: ['presupposition',
#   'construction',
#   'constraint',
#   'control',
#   'logic',
#   'lexical',
#   'type',
#   'class',
#   'information',
#   'categorial'],
#  42: ['construction',
#   'training',
#   'verb',
#   'data',
#   'learning',
#   'control',
#   'inference',
#   'language',
#   'statistical',
#   'cluster'],
#  43: ['type',
#   'class',
#   'verb',
#   'corpus',
#   'possessive',
#   'compound',
#   'construction',
#   'inference',
#   'scheme',
#   'tagger'],
#  44: ['nlg',
#   'construction',
#   'class',
#   'lexical',
#   'system',
#   'collocation',
#   'input',
#   'parser',
#   'vehicle',
#   'lexicon'],
#  45: ['parse',
#   'probability',
#   'np',
#   'cache',
#   'parsing',
#   'construction',
#   'antecedent',
#   'parser',
#   'verb',
#   'compound'],
#  46: ['temporal',
#   'expression',
#   'event',
#   'speech',
#   'presupposition',
#   'recognition',
#   'lexical',
#   'referring',
#   'translation',
#   'tense'],
#  47: ['complexity',
#   'equation',
#   'colour',
#   'inference',
#   'ellipsis',
#   'lexical',
#   'antecedent',
#   'possessive',
#   'semantic',
#   'parsing'],
#  48: ['possessive',
#   'presupposition',
#   'lexical',
#   'type',
#   'similarity',
#   'datr',
#   'np',
#   'semantic',
#   'pronoun',
#   'node'],
#  49: ['node',
#   'construction',
#   'compound',
#   'noun',
#   'probability',
#   'verb',
#   'similarity',
#   'phrase',
#   'temporal',
#   'translation'],
#  50: ['generation',
#   'constraint',
#   'datr',
#   'possessive',
#   'method',
#   'complexity',
#   'inference',
#   'approach',
#   'learning',
#   'data'],
#  51: ['cache',
#   'probability',
#   'lexical',
#   'parsing',
#   'stack',
#   'expression',
#   'unknown',
#   'translation',
#   'class',
#   'guessing'],
#  52: ['referring',
#   'obligation',
#   'expression',
#   'plan',
#   'generation',
#   'goal',
#   'nlg',
#   'tone',
#   'intention',
#   'type'],
#  53: ['tone',
#   'lexical',
#   'transcription',
#   'verb',
#   'nlg',
#   'possessive',
#   'search',
#   'antecedent',
#   'presupposition',
#   'sequence'],
#  54: ['information',
#   'cache',
#   'site',
#   'dialect',
#   'meaning',
#   'node',
#   'nonmonotonic',
#   'class',
#   'construction',
#   'complexity'],
#  55: ['class',
#   'processing',
#   'information',
#   'transfer',
#   'recognition',
#   'cache',
#   'nonmonotonic',
#   'approach',
#   'category',
#   'morphological'],
#  56: ['semantics',
#   'class',
#   'probability',
#   'complexity',
#   'similarity',
#   'tone',
#   'phrase',
#   'number',
#   'sr',
#   'compositional'],
#  57: ['dialect',
#   'site',
#   'distance',
#   'tone',
#   'form',
#   'entropy',
#   'constraint',
#   'cache',
#   'np',
#   'probability'],
#  58: ['construction',
#   'probability',
#   'linguistic',
#   'unknown',
#   'guessing',
#   'cache',
#   'collocation',
#   'training',
#   'category',
#   'dictionary'],
#  59: ['discovery',
#   'dialect',
#   'collocation',
#   'method',
#   'site',
#   'learning',
#   'verb',
#   'information',
#   'similarity',
#   'tone'],
#  60: ['presupposition',
#   'referring',
#   'magic',
#   'collocation',
#   'plan',
#   'method',
#   'pitch',
#   'expression',
#   'meaning',
#   'assumption'],
#  61: ['learning',
#   'collocation',
#   'error',
#   'similarity',
#   'parser',
#   'antecedent',
#   'analysis',
#   'magic',
#   'complexity',
#   'information'],
#  62: ['semantic',
#   'presupposition',
#   'pitch',
#   'accent',
#   'category',
#   'discovery',
#   'constraint',
#   'meaning',
#   'similarity',
#   'analysis'],
#  63: ['ellipsis',
#   'antecedent',
#   'default',
#   'similarity',
#   'input',
#   'magic',
#   'parse',
#   'sign',
#   'substitution',
#   'generation'],
#  64: ['parse',
#   'complexity',
#   'tone',
#   'information',
#   'collocation',
#   'probability',
#   'magic',
#   'possessive',
#   'transcription',
#   'ellipsis'],
#  65: ['magic',
#   'node',
#   'possessive',
#   'collocation',
#   'similarity',
#   'syntactic',
#   'entropy',
#   'data',
#   'construction',
#   'discovery'],
#  66: ['default',
#   'input',
#   'datr',
#   'discovery',
#   'linguistic',
#   'handling',
#   'path',
#   'transfer',
#   'construction',
#   'possessive'],
#  67: ['data',
#   'inference',
#   'auxiliary',
#   'lfg',
#   'compound',
#   'representation',
#   'entropy',
#   'generic',
#   'similarity',
#   'temporal'],
#  68: ['semantic',
#   'collocation',
#   'meaning',
#   'sign',
#   'pitch',
#   'accent',
#   'datr',
#   'probability',
#   'category',
#   'possessive'],
#  69: ['discovery',
#   'transfer',
#   'magic',
#   'collocation',
#   'process',
#   'french',
#   'dialect',
#   'linguistic',
#   'site',
#   'node'],
#  70: ['error',
#   'magic',
#   'coreference',
#   'focus',
#   'utterance',
#   'pragmatic',
#   'theory',
#   'generic',
#   'calculus',
#   'meaning'],
#  71: ['magic',
#   'collocation',
#   'discovery',
#   'semantics',
#   'derivation',
#   'parser',
#   'unification',
#   'data',
#   'logic',
#   'distribution'],
#  72: ['discovery',
#   'temporal',
#   'value',
#   'sign',
#   'data',
#   'verb',
#   'generation',
#   'section',
#   'compound',
#   'distribution'],
#  73: ['lfg',
#   'data',
#   'fstructure',
#   'meaning',
#   'incremental',
#   'magic',
#   'calculus',
#   'structure',
#   'categorial',
#   'training'],
#  74: ['generic',
#   'input',
#   'transfer',
#   'parsing',
#   'one',
#   'hypothesis',
#   'acquisition',
#   'event',
#   'syntactic',
#   'attributevalue'],
#  75: ['discovery',
#   'compound',
#   'probability',
#   'number',
#   'cache',
#   'goal',
#   'coreference',
#   'linguistic',
#   'segment',
#   'knowledge'],
#  76: ['magic',
#   'segment',
#   'discovery',
#   'coreference',
#   'parse',
#   'icon',
#   'generic',
#   'categorial',
#   'sign',
#   'tfs'],
#  77: ['semantics',
#   'focus',
#   'goal',
#   'discourse',
#   'parsing',
#   'discovery',
#   'length',
#   'french',
#   'construction',
#   'generic'],
#  78: ['event',
#   'parser',
#   'jack',
#   'compound',
#   'coreference',
#   'learning',
#   'construction',
#   'cache',
#   'path',
#   'object'],
#  79: ['focus',
#   'approach',
#   'entropy',
#   'punctuation',
#   'similarity',
#   'number',
#   'parser',
#   'chunk',
#   'verb',
#   'parse'],
#  80: ['parsing',
#   'pragmatic',
#   'form',
#   'complexity',
#   'inference',
#   'prolog',
#   'existence',
#   'utterance',
#   'calculus',
#   'evidence'],
#  81: ['parser',
#   'parsing',
#   'presupposition',
#   'magic',
#   'pragmatic',
#   'hypothesis',
#   'probability',
#   'chunk',
#   'translation',
#   'node'],
#  82: ['parsing',
#   'coreference',
#   'error',
#   'sr',
#   'form',
#   'default',
#   'technique',
#   'prolog',
#   'acquisition',
#   'instance'],
#  83: ['parser',
#   'discovery',
#   'magic',
#   'error',
#   'generic',
#   'auxiliary',
#   'robust',
#   'parsing',
#   'description',
#   'event'],
#  84: ['similarity',
#   'pruning',
#   'fsa',
#   'transfer',
#   'complexity',
#   'focus',
#   'event',
#   'jack',
#   'constituent',
#   'specialization'],
#  85: ['lfg',
#   'presupposition',
#   'pragmatic',
#   'transfer',
#   'fstructure',
#   'tableau',
#   'information',
#   'icon',
#   'bin',
#   'auxiliary'],
#  86: ['focus',
#   'existence',
#   'state',
#   'default',
#   'translation',
#   'string',
#   'fsa',
#   'object',
#   'punctuation',
#   'operator'],
#  87: ['fsa',
#   'collocation',
#   'bin',
#   'compound',
#   'item',
#   'goal',
#   'string',
#   'hypothesis',
#   'punctuation',
#   'morpheme'],
#  88: ['lfg',
#   'segment',
#   'default',
#   'topic',
#   'fstructure',
#   'icon',
#   'jack',
#   'event',
#   'semantic',
#   'gapping'],
#  89: ['fsa',
#   'input',
#   'intersection',
#   'incremental',
#   'auxiliary',
#   'dcg',
#   'existence',
#   'punctuation',
#   'hpsg',
#   'distribution'],
#  90: ['punctuation',
#   'auxiliary',
#   'representation',
#   'german',
#   'error',
#   'machine',
#   'tfs',
#   'fsa',
#   'mark',
#   'constituent'],
#  91: ['entropy',
#   'pitch',
#   'translation',
#   'method',
#   'accent',
#   'japanese',
#   'probability',
#   'category',
#   'character',
#   'semantics'],
#  92: ['existence',
#   'entropy',
#   'focus',
#   'compound',
#   'pragmatic',
#   'jack',
#   'attributevalue',
#   'collocation',
#   'event',
#   'verb'],
#  93: ['discovery',
#   'parser',
#   'existence',
#   'training',
#   'fsa',
#   'error',
#   'lexicon',
#   'distribution',
#   'hpsg',
#   'hypothesis'],
#  94: ['fsa',
#   'distribution',
#   'hypothesis',
#   'constituent',
#   'intersection',
#   'type',
#   'pruning',
#   'accuracy',
#   'natural',
#   'cache'],
#  95: ['action',
#   'description',
#   'compound',
#   'linguistic',
#   'bin',
#   'boundary',
#   'dependency',
#   'item',
#   'segmentation',
#   'english'],
#  96: ['entropy',
#   'entry',
#   'probability',
#   'bigram',
#   'discovery',
#   'value',
#   'estimate',
#   'rhetorical',
#   'result',
#   'cooccurrence'],
#  97: ['entropy',
#   'decision',
#   'constituent',
#   'error',
#   'decisiontree',
#   'icon',
#   'pruning',
#   'merging',
#   'hypothesis',
#   'time'],
#  98: ['rhetorical',
#   'icon',
#   'abstract',
#   'entry',
#   'prolog',
#   'clustering',
#   'accuracy',
#   'parser',
#   'string',
#   'network'],
#  99: ['fsa',
#   'anaphor',
#   'obligation',
#   'embedded',
#   'level',
#   'focusing',
#   'focus',
#   'intersection',
#   'icon',
#   'action'],
#  100: ['action',
#   'focus',
#   'dialogue',
#   'icon',
#   'default',
#   'proposal',
#   'punctuation',
#   'assumption',
#   'pragmatic',
#   'problemsolving'],
#  101: ['error',
#   'hpsg',
#   'transfer',
#   'auxiliary',
#   'state',
#   'action',
#   'constituent',
#   'obligation',
#   'pruning',
#   'merging'],
#  102: ['icon',
#   'error',
#   'rhetorical',
#   'tagset',
#   'temporal',
#   'parser',
#   'entry',
#   'spelling',
#   'coreference',
#   'german'],
#  103: ['clustering',
#   'attachment',
#   'tagset',
#   'using',
#   'rhetorical',
#   'suffix',
#   'thesaurus',
#   'estimate',
#   'lexicon',
#   'used'],
#  104: ['error',
#   'fsa',
#   'spelling',
#   'input',
#   'attachment',
#   'argument',
#   'tncb',
#   'auxiliary',
#   'symbol',
#   'intersection'],
#  105: ['segment',
#   'error',
#   'boundary',
#   'distance',
#   'par',
#   'existence',
#   'information',
#   'rhetorical',
#   'vector',
#   'set'],
#  106: ['cooccurrence',
#   'vector',
#   'category',
#   'transfer',
#   'lfg',
#   'character',
#   'distance',
#   'par',
#   'context',
#   'bin'],
#  107: ['icon',
#   'lfg',
#   'input',
#   'method',
#   'magic',
#   'category',
#   'machine',
#   'tfs',
#   'error',
#   'action'],
#  108: ['rhetorical',
#   'entry',
#   'input',
#   'accuracy',
#   'par',
#   'robust',
#   'generic',
#   'segment',
#   'punctuation',
#   'symbol'],
#  109: ['tagset',
#   'generation',
#   'type',
#   'category',
#   'test',
#   'order',
#   'entry',
#   'tagsets',
#   'kanzi',
#   'morpheme'],
#  110: ['spelling',
#   'transfer',
#   'hpsg',
#   'twolevel',
#   'auxiliary',
#   'punctuation',
#   'type',
#   'lfg',
#   'cooccurrence',
#   'description'],
#  111: ['entry',
#   'form',
#   'clustering',
#   'spelling',
#   'transfer',
#   'lemma',
#   'data',
#   'par',
#   'input',
#   'error'],
#  112: ['statistical',
#   'rhetorical',
#   'topic',
#   'error',
#   'segment',
#   'punctuation',
#   'accuracy',
#   'po',
#   'morpheme',
#   'abstract'],
#  113: ['tncb',
#   'german',
#   'french',
#   'rhetorical',
#   'target',
#   'lfg',
#   'element',
#   'pitch',
#   'bag',
#   'complexity'],
#  114: ['attachment',
#   'context',
#   'vector',
#   'tagset',
#   'decision',
#   'accuracy',
#   'cooccurrence',
#   'distance',
#   'treelowering',
#   'new'],
#  115: ['spelling',
#   'rhetorical',
#   'order',
#   'decision',
#   'evaluation',
#   'robust',
#   'symbol',
#   'tncb',
#   'parallel',
#   'coordination'],
#  116: ['class',
#   'transfer',
#   'boundary',
#   'technique',
#   'par',
#   'tncb',
#   'robust',
#   'decisiontree',
#   'spoken',
#   'pitch'],
#  117: ['rhetorical',
#   'punctuation',
#   'german',
#   'decision',
#   'formalism',
#   'bigram',
#   'using',
#   'decisiontree',
#   'robust',
#   'concept'],
#  118: ['topic',
#   'participant',
#   'cue',
#   'punctuation',
#   'par',
#   'shift',
#   'segment',
#   'rhetorical',
#   'symbol',
#   'robust'],
#  119: ['punctuation',
#   'lfg',
#   'decision',
#   'mark',
#   'similarity',
#   'probability',
#   'head',
#   'attachment',
#   'decisiontree',
#   'class'],
#  120: ['robust',
#   'decision',
#   'morpheme',
#   'rate',
#   'icon',
#   'similaritybased',
#   'error',
#   'bigram',
#   'form',
#   'decisiontree'],
#  121: ['clustering',
#   'accuracy',
#   'tagset',
#   'order',
#   'transfer',
#   'icon',
#   'hypothesis',
#   'bin',
#   'punctuation',
#   'german'],
#  122: ['clustering',
#   'icon',
#   'tncb',
#   'transfer',
#   'use',
#   'lhip',
#   'task',
#   'analysis',
#   'island',
#   'pitch'],
#  123: ['entry',
#   'twolevel',
#   'transition',
#   'punctuation',
#   'attachment',
#   'error',
#   'tagging',
#   'syntactic',
#   'unificationbased',
#   'lemma'],
#  124: ['bin',
#   'transition',
#   'statistical',
#   'kanzi',
#   'character',
#   'dependency',
#   'morpheme',
#   'po',
#   'argument',
#   'pitch'],
#  125: ['repair',
#   'lambek',
#   'linguistic',
#   'analysis',
#   'german',
#   'hmm',
#   'speech',
#   'transition',
#   'disambiguation',
#   'bin'],
#  126: ['order',
#   'wo',
#   'pitch',
#   'category',
#   'form',
#   'ordering',
#   'lambek',
#   'accuracy',
#   'statistical',
#   'text'],
#  127: ['rhetorical',
#   'transition',
#   'message',
#   'lambek',
#   'technique',
#   'language',
#   'po',
#   'class',
#   'corpus',
#   'island'],
#  128: ['coordination',
#   'parallel',
#   'bin',
#   'tncb',
#   'statistical',
#   'property',
#   'insideoutside',
#   'lfg',
#   'task',
#   'morpheme'],
#  129: ['parallel',
#   'theta',
#   'tgl',
#   'generation',
#   'german',
#   'coordination',
#   'must',
#   'lambek',
#   'xbar',
#   'tagset'],
#  130: ['parallel',
#   'collocate',
#   'punctuation',
#   'text',
#   'processing',
#   'error',
#   'preposition',
#   'motion',
#   'wo',
#   'logic'],
#  131: ['lambek',
#   'argument',
#   'twolevel',
#   'dependency',
#   'punctuation',
#   'mark',
#   'table',
#   'tagging',
#   'suffix',
#   'po'],
#  132: ['german',
#   'vowel',
#   'task',
#   'error',
#   'warrant',
#   'ordering',
#   'wo',
#   'order',
#   'tgl',
#   'boundary'],
#  133: ['clustering',
#   'warrant',
#   'motion',
#   'contribution',
#   'punctuation',
#   'task',
#   'linear',
#   'show',
#   'text',
#   'technique'],
#  134: ['message',
#   'wo',
#   'attribute',
#   'ordering',
#   'lambek',
#   'approach',
#   'calculus',
#   'tgl',
#   'pitch',
#   'order'],
#  135: ['message',
#   'transition',
#   'parallel',
#   'test',
#   'formalism',
#   'collocate',
#   'accuracy',
#   'unknown',
#   'handtagged',
#   'insideoutside'],
#  136: ['message',
#   'clustering',
#   'entry',
#   'repair',
#   'lambek',
#   'statistical',
#   'list',
#   'qlf',
#   'unknown',
#   'pitch'],
#  137: ['motion',
#   'preposition',
#   'support',
#   'spatial',
#   'light',
#   'lambek',
#   'frequency',
#   'relative',
#   'location',
#   'transition'],
#  138: ['message',
#   'motion',
#   'lambek',
#   'theory',
#   'preposition',
#   'contextfree',
#   'spatial',
#   'attribute',
#   'generate',
#   'distinct'],
#  139: ['message',
#   'attribute',
#   'warrant',
#   'communicative',
#   'task',
#   'explicitwarrant',
#   'distinct',
#   'cost',
#   'wo',
#   'retrieval'],
#  140: ['message',
#   'german',
#   'wo',
#   'lambek',
#   'ordering',
#   'unknown',
#   'test',
#   'use',
#   'head',
#   'rhetorical'],
#  141: ['lambek',
#   'calculus',
#   'transition',
#   'figure',
#   'plan',
#   'pitch',
#   'tgl',
#   'segment',
#   'clustering',
#   'po'],
#  142: ['tgl',
#   'solution',
#   'generated',
#   'form',
#   'conflict',
#   'transition',
#   'german',
#   'calculus',
#   'example',
#   'lambek'],
#  143: ['motion',
#   'gender',
#   'theory',
#   'tgl',
#   'german',
#   'plural',
#   'transformation',
#   'collocate',
#   'person',
#   'rate'],
#  144: ['motion',
#   'preposition',
#   'logic',
#   'languagetheoretic',
#   'german',
#   'spatial',
#   'tgl',
#   'property',
#   'transfer',
#   'instance'],
#  145: ['tagset',
#   'mapping',
#   'generation',
#   'plan',
#   'technique',
#   'categorial',
#   'german',
#   'sr',
#   'transition',
#   'evaluation'],
#  146: ['tgl',
#   'section',
#   'collocate',
#   'test',
#   'evaluation',
#   'lexicalized',
#   'transition',
#   'accuracy',
#   'lig',
#   'motion'],
#  147: ['transition',
#   'variable',
#   'collocate',
#   'weak',
#   'twolevel',
#   'hierarchy',
#   'motion',
#   'test',
#   'dimension',
#   'inheritance'],
#  148: ['segment',
#   'lcp',
#   'countability',
#   'morpheme',
#   'rate',
#   'countable',
#   'vowel',
#   'ks',
#   'lambek',
#   'german'],
#  149: ['countability',
#   'english',
#   'countable',
#   'lexicalized',
#   'form',
#   'mapping',
#   'referential',
#   'known',
#   'segment',
#   'unknown'],
#  150: ['would',
#   'pair',
#   'x',
#   'passage',
#   'vowel',
#   'transition',
#   'countability',
#   'past',
#   'simple',
#   'tagging'],
#  151: ['object',
#   'transition',
#   'argument',
#   'relation',
#   'handtagged',
#   'linguistic',
#   'past',
#   'passage',
#   'countability',
#   'reestimation'],
#  152: ['expert',
#   'dependency',
#   'countability',
#   'german',
#   'sr',
#   'provided',
#   'countable',
#   'teleman',
#   'accuracy',
#   'segment'],
#  153: ['transition',
#   'dependency',
#   'property',
#   'expert',
#   'formalism',
#   'languagetheoretic',
#   'bin',
#   'argument',
#   'passage',
#   'generated'],
#  154: ['time',
#   'teleman',
#   'past',
#   'passage',
#   'distribution',
#   'countability',
#   'theta',
#   'wo',
#   'new',
#   'tagger'],
#  155: ['lexicalized',
#   'accuracy',
#   'transition',
#   'lcp',
#   'rate',
#   'segment',
#   'spoken',
#   'show',
#   'wo',
#   'mapping'],
#  156: ['expert',
#   'lcp',
#   'segment',
#   'network',
#   'tagger',
#   'tagset',
#   'probabilistic',
#   'unit',
#   'provided',
#   'accuracy'],
#  157: ['countability',
#   'countable',
#   'lexicalized',
#   'referential',
#   'article',
#   'dependency',
#   'expert',
#   'lcp',
#   'segment',
#   'operator'],
#  158: ['operator',
#   'presentation',
#   'countability',
#   'x',
#   'pair',
#   'countable',
#   'referential',
#   'direct',
#   'proof',
#   'article'],
#  159: ['network',
#   'selection',
#   'dependency',
#   'heuristic',
#   'informationtheoretical',
#   'matrix',
#   'two',
#   'parse',
#   'unit',
#   'text'],
#  160: ['matrix',
#   'tagger',
#   'twolevel',
#   'morphological',
#   'entry',
#   'form',
#   'nonlinear',
#   'morpheme',
#   'english',
#   'allomorph'],
#  161: ['presentation',
#   'operator',
#   'proof',
#   'subproofs',
#   'planning',
#   'presenting',
#   'network',
#   'proverb',
#   'topdown',
#   'focus'],
#  162: ['network',
#   'dependency',
#   'lexicalized',
#   'heuristic',
#   'selection',
#   'seek',
#   'unit',
#   'informationtheoretical',
#   'scheme',
#   'expert'],
#  163: ['dependency',
#   'seek',
#   'xbar',
#   'compound',
#   'matrix',
#   'slot',
#   'head',
#   'contribution',
#   'stacked',
#   'dg'],
#  164: ['seek',
#   'matrix',
#   'contribution',
#   'expert',
#   'provided',
#   'quantifier',
#   'operator',
#   'coordination',
#   'centering',
#   'equivalence'],
#  165: ['dependency',
#   'network',
#   'heuristic',
#   'matrix',
#   'seek',
#   'informationtheoretical',
#   'categorial',
#   'selection',
#   'original',
#   'xbar'],
#  166: ['heuristic',
#   'equivalence',
#   'dependency',
#   'original',
#   'nonterminal',
#   'object',
#   'theta',
#   'satisfiable',
#   'input',
#   'one'],
#  167: ['accident',
#   'parameter',
#   'text',
#   'tagging',
#   'segment',
#   'lcp',
#   'able',
#   'instance',
#   'also',
#   'tagger'],
#  168: ['centering',
#   'suffix',
#   'realized',
#   'morphological',
#   'alteration',
#   'accident',
#   'continuing',
#   'retaining',
#   'using',
#   'preference'],
#  169: ['centering',
#   'alteration',
#   'suffix',
#   'morphological',
#   'endingguessing',
#   'tagger',
#   'simple',
#   'additional',
#   'original',
#   'rulesets'],
#  170: ['original',
#   'vehicle',
#   'b',
#   'factual',
#   'parameter',
#   'category',
#   'tagging',
#   'accident',
#   'able',
#   'text'],
#  171: ['categorial',
#   'natural',
#   'syntax',
#   'domain',
#   'composition',
#   'morphology',
#   'argument',
#   'change',
#   'error',
#   'membrane'],
#  172: ['original',
#   'tagging',
#   'part',
#   'tag',
#   'heuristic',
#   'tagsets',
#   'reduced',
#   'using',
#   'without',
#   'tagger'],
#  173: ['error',
#   'processing',
#   'vowel',
#   'adjunct',
#   'cooperative',
#   'centering',
#   'susanne',
#   'categorial',
#   'spelling',
#   'punctuation'],
#  174: ['parameter',
#   'error',
#   'genre',
#   'vowel',
#   'cooperative',
#   'discriminant',
#   'adjunct',
#   'certain',
#   'processing',
#   'rate'],
#  175: ['membrane',
#   'composition',
#   'planning',
#   'natural',
#   'requires',
#   'lambdacalculus',
#   'syntax',
#   'domain',
#   'problem',
#   'role'],
#  176: ['planning',
#   'determination',
#   'content',
#   'textplanning',
#   'applied',
#   'and',
#   'perform',
#   'information',
#   'conference',
#   'fluent'],
#  177: ['parent',
#   'ltag',
#   'auxtree',
#   'leaf',
#   'planning',
#   'u',
#   'allows',
#   'encode',
#   'relation',
#   'encoding'],
#  178: ['programming',
#   'higherorder',
#   'ccg',
#   'coordination',
#   'implement',
#   'miller',
#   'dale',
#   'abstract',
#   'categorial',
#   'use'],
#  179: ['referent',
#   'dousha',
#   'conference',
#   'resolution',
#   'reference',
#   'ga',
#   'company',
#   'proceeding',
#   'finding',
#   '96']}
